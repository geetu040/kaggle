# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Loading Dataset
#
# - The dataset has been published by [Möbius](https://www.kaggle.com/arashnic) on [Kaggle](https://www.kaggle.com). You can access the data by following the [data link](https://www.kaggle.com/datasets/arashnic/book-recommendation-dataset)
# - You can download the dataset using the API command, but make sure you have Kaggle's API credentials
# ```
# kaggle datasets download -d arashnic/book-recommendation-dataset
# ```
# - Here I have already downloaded the dataset in "data" folder, so I can just load it in pandas like below

# %%
import pandas as pd

books = pd.read_csv("data/Books.csv")
users = pd.read_csv("data/Users.csv")
ratings = pd.read_csv("data/Ratings.csv")

print("Books Shape:", books.shape)
print("Users Shape:", users.shape)
print("Ratings Shape:", ratings.shape)
# Out:
# Books Shape: (271360, 8)
#
# Users Shape: (278858, 3)
#
# Ratings Shape: (1149780, 3)

# %%
books.sample(3)
# Out:
#               ISBN                                         Book-Title  \
# 58378   0140436766  Hope Leslie, Or, Early Times in the Massachuse...
# 153962  0380774445         The Man Who Shorted Out the Electric Chair
# 76407   0307020134  Ten items or less: A counting book (A Little g...
#
#                      Book-Author Year-Of-Publication  \
# 58378   Catharine Maria Sedgwick                1998
# 153962           Mitchell Symons                1996
# 76407        Stephanie Calmenson                1985
#
#                                  Publisher  \
# 58378                        Penguin Books
# 153962  Harper Mass Market Paperbacks (Mm)
# 76407                      Western Pub. Co
#
#                                               Image-URL-S  \
# 58378   http://images.amazon.com/images/P/0140436766.0...
# 153962  http://images.amazon.com/images/P/0380774445.0...
# 76407   http://images.amazon.com/images/P/0307020134.0...
#
#                                               Image-URL-M  \
# 58378   http://images.amazon.com/images/P/0140436766.0...
# 153962  http://images.amazon.com/images/P/0380774445.0...
# 76407   http://images.amazon.com/images/P/0307020134.0...
#
#                                               Image-URL-L
# 58378   http://images.amazon.com/images/P/0140436766.0...
# 153962  http://images.amazon.com/images/P/0380774445.0...
# 76407   http://images.amazon.com/images/P/0307020134.0...

# %%
users.sample(3)
# Out:
#         User-ID                             Location   Age
# 48846     48847  edinburgh, scotland, united kingdom  21.0
# 39109     39110               mons, hainaut, belgium   NaN
# 265326   265327              bremen, bremen, germany  19.0

# %%
ratings.sample(3)
# Out:
#         User-ID        ISBN  Book-Rating
# 660290   160401  0786890436            0
# 211697    49144  8466605029            5
# 804705   195694  0451183843            0

# %% [markdown]
# # Merging All DataFrames

# %%
# Merging Books and Ratings
merged = ratings.merge(books, on="ISBN")

# Merging Users
merged = merged.merge(users, on="User-ID")

# printing shape of merged dataframe
print("Shape:", merged.shape)

# Showing 3 random samples
merged.sample(3)
# Out:
# Shape: (1031136, 12)
#         User-ID        ISBN  Book-Rating  \
# 720703   106131  0380804557            0
# 83107    113519  0316902918            0
# 936084   201792  0440904935            3
#
#                                                Book-Title  Book-Author  \
# 720703                                           Stardust  Neil Gaiman
# 83107   Bob Vila's Guide to Buying Your Dream House (B...     Bob Vila
# 936084                         The Boy Who Drank Too Much  SHEP GREENE
#
#        Year-Of-Publication      Publisher  \
# 720703                2003           Avon
# 83107                 1990  Little, Brown
# 936084                1980     Laure Leaf
#
#                                               Image-URL-S  \
# 720703  http://images.amazon.com/images/P/0380804557.0...
# 83107   http://images.amazon.com/images/P/0316902918.0...
# 936084  http://images.amazon.com/images/P/0440904935.0...
#
#                                               Image-URL-M  \
# 720703  http://images.amazon.com/images/P/0380804557.0...
# 83107   http://images.amazon.com/images/P/0316902918.0...
# 936084  http://images.amazon.com/images/P/0440904935.0...
#
#                                               Image-URL-L  \
# 720703  http://images.amazon.com/images/P/0380804557.0...
# 83107   http://images.amazon.com/images/P/0316902918.0...
# 936084  http://images.amazon.com/images/P/0440904935.0...
#
#                            Location   Age
# 720703        lorton, virginia, usa  32.0
# 83107   pleasanton, california, usa   NaN
# 936084      tacoma, washington, usa  21.0

# %% [markdown]
# # Removing Duplicates

# %%
merged = merged[~ merged.duplicated(subset=["User-ID", "Book-Title"], keep='first')]
merged.head(3)
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1     2313  034545104X            5
# 2     2313  0812533550            9
#
#                                       Book-Title       Book-Author  \
# 0                           Flesh Tones: A Novel        M. J. Rose
# 1                           Flesh Tones: A Novel        M. J. Rose
# 2  Ender's Game (Ender Wiggins Saga (Paperback))  Orson Scott Card
#
#   Year-Of-Publication         Publisher  \
# 0                2002  Ballantine Books
# 1                2002  Ballantine Books
# 2                1986         Tor Books
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/0812533550.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/034545104X.0...
# 1  http://images.amazon.com/images/P/034545104X.0...
# 2  http://images.amazon.com/images/P/0812533550.0...
#
#                                          Image-URL-L               Location  \
# 0  http://images.amazon.com/images/P/034545104X.0...      tyler, texas, usa
# 1  http://images.amazon.com/images/P/034545104X.0...  cincinnati, ohio, usa
# 2  http://images.amazon.com/images/P/0812533550.0...  cincinnati, ohio, usa
#
#     Age
# 0   NaN
# 1  23.0
# 2  23.0

# %% [markdown]
# # Saving the Merged Dataset

# %%
merged.to_csv("data/merged.csv", index=False)
